# %% [markdown]
# <a href="https://colab.research.google.com/github/aros0918/ai_3d_model_generater/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/aros0918/ai_3d_model_generater.git
# %cd /content/ai_3d_model_generater
# !pip install -q -r requirements.txt
# !pip install -q torch-ema einops tensorboardX plyfile dearpygui huggingface_hub diffusers accelerate transformers xatlas

# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.1.whl
# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/simple_knn-0.0.0-cp310-cp310-linux_x86_64.1.whl
# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/nvdiffrast-0.3.1-py3-none-any.whl
# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/kiui-0.1.8-py3-none-any.whl
# !apt install -qq -y xvfb

# !pip install torch==2.1.0
# !pip install torchvision==0.16.0
# Out:
# /content
# Cloning into 'ai_3d_model_generater'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 54 (delta 12), reused 54 (delta 12), pack-reused 0
# Receiving objects: 100% (54/54), 15.87 MiB | 12.08 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/ai_3d_model_generater
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 62.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -q einops plyfile dearpygui huggingface_hub diffusers accelerate transformers xatlas trimesh PyMCubes pymeshlab rembg[gpu,cli] omegaconf ninja

# build extension from source (can be slow)
# !git clone --recursive https://github.com/ashawkey/diff-gaussian-rasterization
# !pip install -q ./diff-gaussian-rasterization
# !pip install -q ./simple-knn

# pre-built wheels (faster)
# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.1.whl
# !pip install -q https://github.com/camenduru/diff-gaussian-rasterization/releases/download/v1.0/simple_knn-0.0.0-cp310-cp310-linux_x86_64.1.whl

# nvdiffrast
# !pip install -q git+https://github.com/NVlabs/nvdiffrast

# kiuikit
# !pip install -q git+https://github.com/ashawkey/kiuikit
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !sudo apt-get update
# !sudo apt-get -y install nvidia-cuda-toolkit
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [51.0 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,619 kB]
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...

# %%
# !python gradio_app.py
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://424e850b3c3fe23c07.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# python process.py tmp_data/tmp.png
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 690GB/s]
# [INFO] loading image tmp_data/tmp.png...
# [INFO] background removal...
# [INFO] recenter...
# [INFO] load image from tmp_data/tmp_rgba.png...
# Number of points at initialisation :  5000
# [INFO] loading zero123...
# 2024-03-20 19:29:19.095742: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python main2.py --config /content/GaussianImage/configs/image.yaml input=/content/GaussianImage/tmp_data/tmp_rgba.png save_path=tmp mesh_format=glb elevation=0 force_cuda_rast=True

# %%
import trimesh
import numpy as np

# %%
mesh1 = trimesh.load(front)
mesh2 = trimesh.load(side)

# %%
combined = trimesh.util.concatenate( [ mesh1, mesh2 ] )

# %%
combined
